# %%
# 스택 : 하나하나씩 차곡차곡 쌓는다 (append, pop) = 선입후출 구조
stack = []

stack.append(5)
stack.append(2)
stack.append(3)
stack.append(7)
stack.pop()
stack.append(1)
stack.append(4)
stack.pop()

print(stack) # 최하단부터 출력
print(stack[::-1]) # 최상단부터 출력
# Out:
# [5, 2, 3, 1]
# [1, 3, 2, 5]

# %%
# 큐 : 대기줄 = 선입선출 구조
from collections import deque

queue = deque()

queue.append(5)
queue.append(2)
queue.append(3)
queue.append(7)
queue.popleft()
queue.append(1)
queue.append(4)
queue.popleft()

print(queue) # 먼저 들어온 순서대로 출력
queue.reverse() # 다음 출력을 위해 역순으로 바꾸기
print(queue)
# Out:
# deque([3, 7, 1, 4])
# deque([4, 1, 7, 3])

# %%
# 재귀함수 : 자기자신을 호출하는 함수
def recursive_function():
    print('재귀함수 호출')
    recursive_function()

recursive_function()
# Out:
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# 재귀함수 호출
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-3-70109cceda1e> in <cell line: 0>()
#       4     recursive_function()
#       5
# ----> 6 recursive_function()
#
# <ipython-input-3-70109cceda1e> in recursive_function()
#       2 def recursive_function():
#       3     print('재귀함수 호출')
# ----> 4     recursive_function()
#       5
#       6 recursive_function()
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-3-70109cceda1e> in recursive_function()
#       2 def recursive_function():
#       3     print('재귀함수 호출')
# ----> 4     recursive_function()
#       5
#       6 recursive_function()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
# 재귀함수 종료
def recursive_function(i):
    if i == 100:
        return
    print(f'{i}번째 재귀 함수에서 {i+1}번째 재귀 함수를 호출')
    recursive_function(i+1)
    print(f'{i}번째 재귀 함수를 종료')

recursive_function(1)
# Out:
# 1번째 재귀 함수에서 2번째 재귀 함수를 호출
# 2번째 재귀 함수에서 3번째 재귀 함수를 호출
# 3번째 재귀 함수에서 4번째 재귀 함수를 호출
# 4번째 재귀 함수에서 5번째 재귀 함수를 호출
# 5번째 재귀 함수에서 6번째 재귀 함수를 호출
# 6번째 재귀 함수에서 7번째 재귀 함수를 호출
# 7번째 재귀 함수에서 8번째 재귀 함수를 호출
# 8번째 재귀 함수에서 9번째 재귀 함수를 호출
# 9번째 재귀 함수에서 10번째 재귀 함수를 호출
# 10번째 재귀 함수에서 11번째 재귀 함수를 호출
# 11번째 재귀 함수에서 12번째 재귀 함수를 호출
# 12번째 재귀 함수에서 13번째 재귀 함수를 호출
# 13번째 재귀 함수에서 14번째 재귀 함수를 호출
# 14번째 재귀 함수에서 15번째 재귀 함수를 호출
# 15번째 재귀 함수에서 16번째 재귀 함수를 호출
# 16번째 재귀 함수에서 17번째 재귀 함수를 호출
# 17번째 재귀 함수에서 18번째 재귀 함수를 호출
# 18번째 재귀 함수에서 19번째 재귀 함수를 호출
# 19번째 재귀 함수에서 20번째 재귀 함수를 호출
# 20번째 재귀 함수에서 21번째 재귀 함수를 호출
# 21번째 재귀 함수에서 22번째 재귀 함수를 호출
# 22번째 재귀 함수에서 23번째 재귀 함수를 호출
# 23번째 재귀 함수에서 24번째 재귀 함수를 호출
# 24번째 재귀 함수에서 25번째 재귀 함수를 호출
# 25번째 재귀 함수에서 26번째 재귀 함수를 호출
# 26번째 재귀 함수에서 27번째 재귀 함수를 호출
# 27번째 재귀 함수에서 28번째 재귀 함수를 호출
# 28번째 재귀 함수에서 29번째 재귀 함수를 호출
# 29번째 재귀 함수에서 30번째 재귀 함수를 호출
# 30번째 재귀 함수에서 31번째 재귀 함수를 호출
# 31번째 재귀 함수에서 32번째 재귀 함수를 호출
# 32번째 재귀 함수에서 33번째 재귀 함수를 호출
# 33번째 재귀 함수에서 34번째 재귀 함수를 호출
# 34번째 재귀 함수에서 35번째 재귀 함수를 호출
# 35번째 재귀 함수에서 36번째 재귀 함수를 호출
# 36번째 재귀 함수에서 37번째 재귀 함수를 호출
# 37번째 재귀 함수에서 38번째 재귀 함수를 호출
# 38번째 재귀 함수에서 39번째 재귀 함수를 호출
# 39번째 재귀 함수에서 40번째 재귀 함수를 호출
# 40번째 재귀 함수에서 41번째 재귀 함수를 호출
# 41번째 재귀 함수에서 42번째 재귀 함수를 호출
# 42번째 재귀 함수에서 43번째 재귀 함수를 호출
# 43번째 재귀 함수에서 44번째 재귀 함수를 호출
# 44번째 재귀 함수에서 45번째 재귀 함수를 호출
# 45번째 재귀 함수에서 46번째 재귀 함수를 호출
# 46번째 재귀 함수에서 47번째 재귀 함수를 호출
# 47번째 재귀 함수에서 48번째 재귀 함수를 호출
# 48번째 재귀 함수에서 49번째 재귀 함수를 호출
# 49번째 재귀 함수에서 50번째 재귀 함수를 호출
# 50번째 재귀 함수에서 51번째 재귀 함수를 호출
# 51번째 재귀 함수에서 52번째 재귀 함수를 호출
# 52번째 재귀 함수에서 53번째 재귀 함수를 호출
# 53번째 재귀 함수에서 54번째 재귀 함수를 호출
# 54번째 재귀 함수에서 55번째 재귀 함수를 호출
# 55번째 재귀 함수에서 56번째 재귀 함수를 호출
# 56번째 재귀 함수에서 57번째 재귀 함수를 호출
# 57번째 재귀 함수에서 58번째 재귀 함수를 호출
# 58번째 재귀 함수에서 59번째 재귀 함수를 호출
# 59번째 재귀 함수에서 60번째 재귀 함수를 호출
# 60번째 재귀 함수에서 61번째 재귀 함수를 호출
# 61번째 재귀 함수에서 62번째 재귀 함수를 호출
# 62번째 재귀 함수에서 63번째 재귀 함수를 호출
# 63번째 재귀 함수에서 64번째 재귀 함수를 호출
# 64번째 재귀 함수에서 65번째 재귀 함수를 호출
# 65번째 재귀 함수에서 66번째 재귀 함수를 호출
# 66번째 재귀 함수에서 67번째 재귀 함수를 호출
# 67번째 재귀 함수에서 68번째 재귀 함수를 호출
# 68번째 재귀 함수에서 69번째 재귀 함수를 호출
# 69번째 재귀 함수에서 70번째 재귀 함수를 호출
# 70번째 재귀 함수에서 71번째 재귀 함수를 호출
# 71번째 재귀 함수에서 72번째 재귀 함수를 호출
# 72번째 재귀 함수에서 73번째 재귀 함수를 호출
# 73번째 재귀 함수에서 74번째 재귀 함수를 호출
# 74번째 재귀 함수에서 75번째 재귀 함수를 호출
# 75번째 재귀 함수에서 76번째 재귀 함수를 호출
# 76번째 재귀 함수에서 77번째 재귀 함수를 호출
# 77번째 재귀 함수에서 78번째 재귀 함수를 호출
# 78번째 재귀 함수에서 79번째 재귀 함수를 호출
# 79번째 재귀 함수에서 80번째 재귀 함수를 호출
# 80번째 재귀 함수에서 81번째 재귀 함수를 호출
# 81번째 재귀 함수에서 82번째 재귀 함수를 호출
# 82번째 재귀 함수에서 83번째 재귀 함수를 호출
# 83번째 재귀 함수에서 84번째 재귀 함수를 호출
# 84번째 재귀 함수에서 85번째 재귀 함수를 호출
# 85번째 재귀 함수에서 86번째 재귀 함수를 호출
# 86번째 재귀 함수에서 87번째 재귀 함수를 호출
# 87번째 재귀 함수에서 88번째 재귀 함수를 호출
# 88번째 재귀 함수에서 89번째 재귀 함수를 호출
# 89번째 재귀 함수에서 90번째 재귀 함수를 호출
# 90번째 재귀 함수에서 91번째 재귀 함수를 호출
# 91번째 재귀 함수에서 92번째 재귀 함수를 호출
# 92번째 재귀 함수에서 93번째 재귀 함수를 호출
# 93번째 재귀 함수에서 94번째 재귀 함수를 호출
# 94번째 재귀 함수에서 95번째 재귀 함수를 호출
# 95번째 재귀 함수에서 96번째 재귀 함수를 호출
# 96번째 재귀 함수에서 97번째 재귀 함수를 호출
# 97번째 재귀 함수에서 98번째 재귀 함수를 호출
# 98번째 재귀 함수에서 99번째 재귀 함수를 호출
# 99번째 재귀 함수에서 100번째 재귀 함수를 호출
# 99번째 재귀 함수를 종료
# 98번째 재귀 함수를 종료
# 97번째 재귀 함수를 종료
# 96번째 재귀 함수를 종료
# 95번째 재귀 함수를 종료
# 94번째 재귀 함수를 종료
# 93번째 재귀 함수를 종료
# 92번째 재귀 함수를 종료
# 91번째 재귀 함수를 종료
# 90번째 재귀 함수를 종료
# 89번째 재귀 함수를 종료
# 88번째 재귀 함수를 종료
# 87번째 재귀 함수를 종료
# 86번째 재귀 함수를 종료
# 85번째 재귀 함수를 종료
# 84번째 재귀 함수를 종료
# 83번째 재귀 함수를 종료
# 82번째 재귀 함수를 종료
# 81번째 재귀 함수를 종료
# 80번째 재귀 함수를 종료
# 79번째 재귀 함수를 종료
# 78번째 재귀 함수를 종료
# 77번째 재귀 함수를 종료
# 76번째 재귀 함수를 종료
# 75번째 재귀 함수를 종료
# 74번째 재귀 함수를 종료
# 73번째 재귀 함수를 종료
# 72번째 재귀 함수를 종료
# 71번째 재귀 함수를 종료
# 70번째 재귀 함수를 종료
# 69번째 재귀 함수를 종료
# 68번째 재귀 함수를 종료
# 67번째 재귀 함수를 종료
# 66번째 재귀 함수를 종료
# 65번째 재귀 함수를 종료
# 64번째 재귀 함수를 종료
# 63번째 재귀 함수를 종료
# 62번째 재귀 함수를 종료
# 61번째 재귀 함수를 종료
# 60번째 재귀 함수를 종료
# 59번째 재귀 함수를 종료
# 58번째 재귀 함수를 종료
# 57번째 재귀 함수를 종료
# 56번째 재귀 함수를 종료
# 55번째 재귀 함수를 종료
# 54번째 재귀 함수를 종료
# 53번째 재귀 함수를 종료
# 52번째 재귀 함수를 종료
# 51번째 재귀 함수를 종료
# 50번째 재귀 함수를 종료
# 49번째 재귀 함수를 종료
# 48번째 재귀 함수를 종료
# 47번째 재귀 함수를 종료
# 46번째 재귀 함수를 종료
# 45번째 재귀 함수를 종료
# 44번째 재귀 함수를 종료
# 43번째 재귀 함수를 종료
# 42번째 재귀 함수를 종료
# 41번째 재귀 함수를 종료
# 40번째 재귀 함수를 종료
# 39번째 재귀 함수를 종료
# 38번째 재귀 함수를 종료
# 37번째 재귀 함수를 종료
# 36번째 재귀 함수를 종료
# 35번째 재귀 함수를 종료
# 34번째 재귀 함수를 종료
# 33번째 재귀 함수를 종료
# 32번째 재귀 함수를 종료
# 31번째 재귀 함수를 종료
# 30번째 재귀 함수를 종료
# 29번째 재귀 함수를 종료
# 28번째 재귀 함수를 종료
# 27번째 재귀 함수를 종료
# 26번째 재귀 함수를 종료
# 25번째 재귀 함수를 종료
# 24번째 재귀 함수를 종료
# 23번째 재귀 함수를 종료
# 22번째 재귀 함수를 종료
# 21번째 재귀 함수를 종료
# 20번째 재귀 함수를 종료
# 19번째 재귀 함수를 종료
# 18번째 재귀 함수를 종료
# 17번째 재귀 함수를 종료
# 16번째 재귀 함수를 종료
# 15번째 재귀 함수를 종료
# 14번째 재귀 함수를 종료
# 13번째 재귀 함수를 종료
# 12번째 재귀 함수를 종료
# 11번째 재귀 함수를 종료
# 10번째 재귀 함수를 종료
# 9번째 재귀 함수를 종료
# 8번째 재귀 함수를 종료
# 7번째 재귀 함수를 종료
# 6번째 재귀 함수를 종료
# 5번째 재귀 함수를 종료
# 4번째 재귀 함수를 종료
# 3번째 재귀 함수를 종료
# 2번째 재귀 함수를 종료
# 1번째 재귀 함수를 종료

# %%
# 팩토리얼 구현하기
def factorial_iteraction(n):
    result = 1
    for i in range(1, n+1):
        result *= i
    return result

def factorial_recursive(n):
    if n <= 1:
        return 1
    return n*factorial_recursive(n-1)

print("반복적으로 구현", factorial_iteraction(5))
print("재귀적으로 구현", factorial_recursive(5))
# Out:
# 반복적으로 구현 120
# 재귀적으로 구현 120

# %%
def solution(progresses, speeds):
    result = [1]
    temp = []

    for i in range(len(progresses)):
        if (100 - progresses[i]) % speeds[i] == 0:
            temp.append((100 - progresses[i]) // speeds[i])
        else:
            temp.append((100 - progresses[i]) // speeds[i] + 1)
    print(temp)

    for i in range(1, len(temp)):
        print(i)
        print(result)
        if temp[i-1] >= temp[i]:
            result[-1] += 1
        else:
            result.append(1)

    return result

# %%
from collections import deque

def solution(progresses, speeds):
    que = deque()
    stack = []

    for i in range(len(progresses)):
        if (100 - progresses[i]) % speeds[i] == 0:
            que.append((100 - progresses[i]) // speeds[i])
        else:
            que.append(((100 - progresses[i]) // speeds[i]) + 1)

    while que:
        x = que.popleft()
        result = 1
        while len(que) >= 1 and x >= que[0]:
            que.popleft()
            result += 1
        stack.append(result)
    return stack

# %%
from collections import deque

def solution(progresses, speeds):
    que = deque()
    stack = []

    for i in range(len(progresses)):
        if (100 - progresses[i]) % speeds[i] == 0:
            que.append((100 - progresses[i]) // speeds[i])
        else:
            que.append(((100 - progresses[i]) // speeds[i]) + 1)

    while que:
        x = que.popleft()
        print('x= ' , x)
        result = 1
        while len(que) >= 1 and x >= que[0]:
            print('q = ', que[0])
            que.popleft()
            result += 1
        print(que)
        stack.append(result)
    return stack

# %%
solution([95, 90, 99, 99, 80, 99], [1, 1, 1, 1, 1, 1])
# Out:
# x=  5
# deque([10, 1, 1, 20, 1])
# x=  10
# q =  1
# q =  1
# deque([20, 1])
# x=  20
# q =  1
# deque([])
# [1, 3, 2]

# %% [markdown]
# ## DFS
#
# ```
# DFS: 깊이 우선 탐색 -> 인접 리스트 & 재귀함수
# ```

# %%
def dfs(graph, v, visited):
    # 현재 노드 방문 처리
    visited[v] = True
    print(v, end = ' ')
    # 현재 노드와 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# 각 노드가 연결된 정보를 리스트 자료형으로 표현(2차원 리스트)
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]
visited = [False] * 9 # 각 노드가 방문된 정보를 리스트 자료형으로 표현(1차원 리스트)
dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %% [markdown]
# ## BFS
# ```
# BFS: 너비 우선 탐색 -> 큐 이용
# ```

# %%
from collections import deque

def bfs(graph, start, visited):
    queue = deque([start])
    # 현재 노드 방문 처리
    visited[start] = True
    # 큐가 빌 때까지 반복
    while queue:
        # 큐에서 하나의 원소를 뽑아 출력
        v = queue.popleft()
        print(v, end = ' ')
        # 해당 원소와 연결된 아직 방문하지 않은 원소들을 큐에 삽입
        for i in graph[v]:
            if not visited[i]:
                queue.append(i)
                visited[i] = True


# 각 노드가 연결된 정보를 리스트 자료형으로 표현(2차원 리스트)
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
    ]

visited = [False] * 9 # 각 노드가 방문된 정보를 리스트 자료형으로 표현(1차원 리스트)
bfs(graph, 1, visited)
# Out:
# 1 2 3 8 7 4 5 6

# %%
n, m = map(int, input().split())

graph = []
for i in range(n):
    graph.append(list(map(int, input())))

def dfs(x, y):
    if x <= -1 or x>=n or y<=-1 or y >= m:
        return False
    if graph[x][y] == 0:
        graph[x][y] = 1
        dfs(x-1, y)
        dfs(x+1, y)
        dfs(x, y-1)
        dfs(x, y+1)
        return True
    print(graph)
    return False

result = 0
for i in range(n):
    for j in range(m):
        if dfs(i, j) == True:
            result +=1

print(result)
# Out:
# 4 5
# 00110
# 00011
# 11111
# 00000
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.

# %% [markdown]
# ## 음료수 얼려먹기
#
# ```
# 해결방안: DFS (백준 1012번 추가 예제)
# ```

# %%
n, m = map(int, input().split())

graph = []
for i in range(n):
    graph.append(list(map(int, input())))

# DFS로 특정 노드를 방문한 뒤에 연결된 모드 노드들도 방문
def dfs(x, y):
    # 주어진 범위를 벗어나는 경우에는 즉시 종료
    if x <= -1 or x >= n or y <= -1 or y >= m:
        return False
    # 현재 노드 방문하지 않았다면
    if graph[x][y] == 0 :
        graph[x][y] = 1 # 방문처리
        dfs(x-1, y) # 상하좌우 위치도 재귀 호출
        dfs(x, y-1)
        dfs(x+1, y)
        dfs(x, y+1)
        return True
    return False

# 모든 노드에 대하여 음료수 채우기
result = 0
for i in range(n):
    for j in range(m):
        if dfs(i, j) == True:
            result +=1

print(result)
# Out:
# 4 5
# 00110
# 00011
# 11111
# 00000
# 3

# %%
t = int(input())

def dfs(x, y):
    if x <= -1 or x >= m or y <= -1 or y >= n:
        return False
    if map_list[x][y] == 1:
        map_list[x][y] = 0

        dfs(x-1,y)
        dfs(x+1, y)
        dfs(x, y-1)
        dfs(x, y+1)

        return True
    return False

for _ in range(t):
    m, n, k = map(int, input().split())

    map_list = [[0]*n for _ in range(m)]
    for _ in range(k):
        x, y = map(int, input().split())
        map_list[x][y] = 1
    ans = 0
    for i in range(m):
        for j in range(n):
            if dfs(i, j) == True:
                ans+=1
    print(ans)
# Out:
# 2
# 10 8 17
# 0 0
# 1 0
# 1 1
# 4 2
# 4 3
# 4 5
# 2 4
# 3 4
# 7 4
# 8 4
# 9 4
# 7 5
# 8 5
# 9 5
# 7 6
# 8 6
# 9 6
# 5
# 10 10 1
# 5 5
# 1

# %% [markdown]
# ## 미로 탈출
#
# ```
# 해결방안 : BFS
# ```

# %%
from collections import deque

n, m = map(int, input().split())
graph = []
for i in range(n):
    graph.append(list(map(int, input())))

# 이동할 방향 (상, 하, 좌, 우)
dx = [-1, 1, 0, 0]
dy = [0, 0, -1, 1]

# BFS 소스코드 구현
def bfs(x, y):
    # 큐 구현을 위해 deque 사용
    queue = deque()
    queue.append((x, y))

    # 큐가 빌 때까지 반복
    while queue:
        x, y = queue.popleft()
        for i in range(4): # 상하좌우
            nx = x + dx[i]
            ny = y + dy[i]
            # 미로 찾기 공간을 벗어난 경우 무시
            if nx < 0 or ny < 0 or nx >= n or ny >= m:
                continue
            # 벽인 경우 무시
            if graph[nx][ny] == 0:
                continue
            # 해당 노드 처음 방문하는 경우에만 최단 거리 기록
            if graph[nx][ny] == 1:
                graph[nx][ny] = graph[x][y] + 1
                queue.append((nx, ny))
    return graph[n-1][m-1]

print(bfs(0, 0))
# Out:
# 5 6
# 101010
# 111111
# 000001
# 111111
# 111111
# 10
